# %% [markdown]
# ### Search Engine With Langchain Tools And Agents

# %%
## Arxiv--Research
## Tools creation
from langchain_community.tools import ArxivQueryRun,WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper,ArxivAPIWrapper

# %%
## Used the inbuilt tool of wikipedia
api_wrapper_wiki=WikipediaAPIWrapper(top_k_results=1,doc_content_chars_max=250)
wiki=WikipediaQueryRun(api_wrapper=api_wrapper_wiki)
wiki.name
# Out:
# 'wikipedia'

# %%
api_wrapper_arxiv=ArxivAPIWrapper(top_k_results=1,doc_content_chars_max=250)
arxiv=ArxivQueryRun(api_wrapper=api_wrapper_arxiv)
print(arxiv.name)
# Out:
# arxiv

# %%
tools=[wiki,arxiv]

# %%
tools
# Out:
# [WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(wiki_client=<module 'wikipedia' from 'c:\\Users\\Kempsly\\Desktop\\Genai_projects\\Q&A-Chatbot\\venv\\Lib\\site-packages\\wikipedia\\__init__.py'>, top_k_results=1, lang='en', load_all_available_meta=False, doc_content_chars_max=250)),
#  ArxivQueryRun(api_wrapper=ArxivAPIWrapper(arxiv_search=<class 'arxiv.Search'>, arxiv_exceptions=(<class 'arxiv.ArxivError'>, <class 'arxiv.UnexpectedEmptyPageError'>, <class 'arxiv.HTTPError'>), top_k_results=1, ARXIV_MAX_QUERY_LENGTH=300, continue_on_failure=False, load_max_docs=100, load_all_available_meta=False, doc_content_chars_max=250))]

# %%
## Custom tools[RAG Tool]
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader=WebBaseLoader("https://docs.smith.langchain.com/")
docs=loader.load()
documents=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200).split_documents(docs)
vectordb=FAISS.from_documents(documents,OpenAIEmbeddings())
retriever=vectordb.as_retriever()
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000296C844B9D0>)

# %%
from langchain.tools.retriever import create_retriever_tool
retriever_tool=create_retriever_tool(retriever,"langsmith-search","Search any information about Langsmith ")

retriever_tool.name
# Out:
# 'langsmith-search'

# %%
tools=[wiki,arxiv,retriever_tool]

# %%
tools
# Out:
# [WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(wiki_client=<module 'wikipedia' from 'c:\\Users\\Kempsly\\Desktop\\Genai_projects\\Q&A-Chatbot\\venv\\Lib\\site-packages\\wikipedia\\__init__.py'>, top_k_results=1, lang='en', load_all_available_meta=False, doc_content_chars_max=250)),
#  ArxivQueryRun(api_wrapper=ArxivAPIWrapper(arxiv_search=<class 'arxiv.Search'>, arxiv_exceptions=(<class 'arxiv.ArxivError'>, <class 'arxiv.UnexpectedEmptyPageError'>, <class 'arxiv.HTTPError'>), top_k_results=1, ARXIV_MAX_QUERY_LENGTH=300, continue_on_failure=False, load_max_docs=100, load_all_available_meta=False, doc_content_chars_max=250)),
#  Tool(name='langsmith-search', description='Search any information about Langsmith ', args_schema=<class 'langchain_core.tools.retriever.RetrieverInput'>, func=functools.partial(<function _get_relevant_documents at 0x00000296B89702C0>, retriever=VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000296C844B9D0>), document_prompt=PromptTemplate(input_variables=['page_content'], template='{page_content}'), document_separator='\n\n'), coroutine=functools.partial(<function _aget_relevant_documents at 0x00000296B8970540>, retriever=VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000296C844B9D0>), document_prompt=PromptTemplate(input_variables=['page_content'], template='{page_content}'), document_separator='\n\n'))]

# %%
# ## Run all this tools with Agents and LLM Models

# ## Tools, LLM-->AgentExecutor
# from langchain_groq import ChatGroq
# from dotenv import load_dotenv
# import openai
# load_dotenv()
# import os

# groq_api_key=os.getenv("GROQ_API_KEY")
# # openai.api_key=os.getenv("OPENAI_API_KEY")
# os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

# llm=ChatGroq(groq_api_key=groq_api_key,model_name="Llama3-8b-8192")

# %%
## Run all this tools with Agents and LLM Models

## Tools, LLM-->AgentExecutor
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import openai
load_dotenv()
import os

groq_api_key=os.getenv("GROQ_API_KEY")
# openai.api_key=os.getenv("OPENAI_API_KEY")


os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

llm=ChatGroq(groq_api_key=groq_api_key,model_name="Llama3-8b-8192")

# %%
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x00000296FF5C8310>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000296FF673E50>, model_name='Llama3-8b-8192', groq_api_key=SecretStr('**********'))

# %%
## Prompt Template
from langchain import hub
prompt=hub.pull("hwchase17/openai-functions-agent")
prompt.messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are a helpful assistant')),
#  MessagesPlaceholder(variable_name='chat_history', optional=True),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')),
#  MessagesPlaceholder(variable_name='agent_scratchpad')]

# %%
## Agents
from langchain.agents import create_openai_tools_agent
agent=create_openai_tools_agent(llm,tools,prompt)
agent
# Out:
# RunnableAssign(mapper={
#   agent_scratchpad: RunnableLambda(lambda x: format_to_openai_tool_messages(x['intermediate_steps']))
# })
# | ChatPromptTemplate(input_variables=['agent_scratchpad', 'input'], optional_variables=['chat_history'], input_types={'chat_history': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]], 'agent_scratchpad': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]]}, partial_variables={'chat_history': []}, metadata={'lc_hub_owner': 'hwchase17', 'lc_hub_repo': 'openai-functions-agent', 'lc_hub_commit_hash': 'a1655024b06afbd95d17449f21316291e0726f13dcfaf990cc0d18087ad689a5'}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are a helpful assistant')), MessagesPlaceholder(variable_name='chat_history', optional=True), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')), MessagesPlaceholder(variable_name='agent_scratchpad')])
# | RunnableBinding(bound=ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x00000296FF5C8310>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000296FF673E50>, model_name='Llama3-8b-8192', groq_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'wikipedia', 'description': 'A wrapper around Wikipedia. Useful for when you need to answer general questions about people, places, companies, facts, historical events, or other subjects. Input should be a search query.', 'parameters': {'type': 'object', 'properties': {'query': {'description': 'query to look up on wikipedia', 'type': 'string'}}, 'required': ['query']}}}, {'type': 'function', 'function': {'name': 'arxiv', 'description': 'A wrapper around Arxiv.org Useful for when you need to answer questions about Physics, Mathematics, Computer Science, Quantitative Biology, Quantitative Finance, Statistics, Electrical Engineering, and Economics from scientific articles on arxiv.org. Input should be a search query.', 'parameters': {'type': 'object', 'properties': {'query': {'description': 'search query to look up', 'type': 'string'}}, 'required': ['query']}}}, {'type': 'function', 'function': {'name': 'langsmith-search', 'description': 'Search any information about Langsmith ', 'parameters': {'type': 'object', 'properties': {'query': {'description': 'query to look up in retriever', 'type': 'string'}}, 'required': ['query']}}}]})
# | OpenAIToolsAgentOutputParser()

# %%
## Agent Executer
from langchain.agents import AgentExecutor
agent_executor=AgentExecutor(agent=agent,tools=tools,verbose=True)
agent_executor
# Out:
# AgentExecutor(verbose=True, agent=RunnableMultiActionAgent(runnable=RunnableAssign(mapper={
#   agent_scratchpad: RunnableLambda(lambda x: format_to_openai_tool_messages(x['intermediate_steps']))
# })
# | ChatPromptTemplate(input_variables=['agent_scratchpad', 'input'], optional_variables=['chat_history'], input_types={'chat_history': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]], 'agent_scratchpad': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]]}, partial_variables={'chat_history': []}, metadata={'lc_hub_owner': 'hwchase17', 'lc_hub_repo': 'openai-functions-agent', 'lc_hub_commit_hash': 'a1655024b06afbd95d17449f21316291e0726f13dcfaf990cc0d18087ad689a5'}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are a helpful assistant')), MessagesPlaceholder(variable_name='chat_history', optional=True), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')), MessagesPlaceholder(variable_name='agent_scratchpad')])
# | RunnableBinding(bound=ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x00000296FF5C8310>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000296FF673E50>, model_name='Llama3-8b-8192', groq_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'wikipedia', 'description': 'A wrapper around Wikipedia. Useful for when you need to answer general questions about people, places, companies, facts, historical events, or other subjects. Input should be a search query.', 'parameters': {'type': 'object', 'properties': {'query': {'description': 'query to look up on wikipedia', 'type': 'string'}}, 'required': ['query']}}}, {'type': 'function', 'function': {'name': 'arxiv', 'description': 'A wrapper around Arxiv.org Useful for when you need to answer questions about Physics, Mathematics, Computer Science, Quantitative Biology, Quantitative Finance, Statistics, Electrical Engineering, and Economics from scientific articles on arxiv.org. Input should be a search query.', 'parameters': {'type': 'object', 'properties': {'query': {'description': 'search query to look up', 'type': 'string'}}, 'required': ['query']}}}, {'type': 'function', 'function': {'name': 'langsmith-search', 'description': 'Search any information about Langsmith ', 'parameters': {'type': 'object', 'properties': {'query': {'description': 'query to look up in retriever', 'type': 'string'}}, 'required': ['query']}}}]})
# | OpenAIToolsAgentOutputParser(), input_keys_arg=[], return_keys_arg=[], stream_runnable=True), tools=[WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(wiki_client=<module 'wikipedia' from 'c:\\Users\\Kempsly\\Desktop\\Genai_projects\\Q&A-Chatbot\\venv\\Lib\\site-packages\\wikipedia\\__init__.py'>, top_k_results=1, lang='en', load_all_available_meta=False, doc_content_chars_max=250)), ArxivQueryRun(api_wrapper=ArxivAPIWrapper(arxiv_search=<class 'arxiv.Search'>, arxiv_exceptions=(<class 'arxiv.ArxivError'>, <class 'arxiv.UnexpectedEmptyPageError'>, <class 'arxiv.HTTPError'>), top_k_results=1, ARXIV_MAX_QUERY_LENGTH=300, continue_on_failure=False, load_max_docs=100, load_all_available_meta=False, doc_content_chars_max=250)), Tool(name='langsmith-search', description='Search any information about Langsmith ', args_schema=<class 'langchain_core.tools.retriever.RetrieverInput'>, func=functools.partial(<function _get_relevant_documents at 0x00000296B89702C0>, retriever=VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000296C844B9D0>), document_prompt=PromptTemplate(input_variables=['page_content'], template='{page_content}'), document_separator='\n\n'), coroutine=functools.partial(<function _aget_relevant_documents at 0x00000296B8970540>, retriever=VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000296C844B9D0>), document_prompt=PromptTemplate(input_variables=['page_content'], template='{page_content}'), document_separator='\n\n'))])

# %%
agent_executor.invoke({"input":"Tell me about Langsmith"})
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 agent_executor.invoke({"input":"Tell me about Langsmith"})
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\chains\base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\chains\base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output, intermediate_steps, run_manager=run_manager
#    1635         )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1331, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1331, in <listcomp>(.0)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1359, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1356     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1358     # Call the LLM to see what to do.
# -> 1359     output = self._action_agent.plan(
#    1360         intermediate_steps,
#    1361         callbacks=run_manager.get_child() if run_manager else None,
#    1362         **inputs,
#    1363     )
#    1364 except OutputParserException as e:
#    1365     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:577, in RunnableMultiActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     569 final_output: Any = None
#     570 if self.stream_runnable:
#     571     # Use streaming to make sure that the underlying LLM is invoked in a
#     572     # streaming
#    (...)
#     575     # Because the response from the plan is not a generator, we need to
#     576     # accumulate the output into final output and return that.
# --> 577     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     578         if final_output is None:
#     579             final_output = chunk
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:3261, in RunnableSequence.stream(self, input, config, **kwargs)
#    3255 def stream(
#    3256     self,
#    3257     input: Input,
#    3258     config: Optional[RunnableConfig] = None,
#    3259     **kwargs: Optional[Any],
#    3260 ) -> Iterator[Output]:
# -> 3261     yield from self.transform(iter([input]), config, **kwargs)
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:3248, in RunnableSequence.transform(self, input, config, **kwargs)
#    3242 def transform(
#    3243     self,
#    3244     input: Iterator[Input],
#    3245     config: Optional[RunnableConfig] = None,
#    3246     **kwargs: Optional[Any],
#    3247 ) -> Iterator[Output]:
# -> 3248     yield from self._transform_stream_with_config(
#    3249         input,
#    3250         self._transform,
#    3251         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3252         **kwargs,
#    3253     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:2054, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2052 try:
#    2053     while True:
# -> 2054         chunk: Output = context.run(next, iterator)  # type: ignore
#    2055         yield chunk
#    2056         if final_output_supported:
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:3211, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3208     else:
#    3209         final_pipeline = step.transform(final_pipeline, config)
# -> 3211 yield from final_pipeline
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:1272, in Runnable.transform(self, input, config, **kwargs)
#    1269 final: Input
#    1270 got_first_val = False
# -> 1272 for ichunk in input:
#    1273     # The default implementation of transform is to buffer input and
#    1274     # then call stream.
#    1275     # It'll attempt to gather all input into a single chunk using
#    1276     # the `+` operator.
#    1277     # If the input is not addable, then we'll assume that we can
#    1278     # only operate on the last chunk,
#    1279     # and we'll iterate until we get to the last chunk.
#    1280     if not got_first_val:
#    1281         final = ichunk
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:5299, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5293 def transform(
#    5294     self,
#    5295     input: Iterator[Input],
#    5296     config: Optional[RunnableConfig] = None,
#    5297     **kwargs: Any,
#    5298 ) -> Iterator[Output]:
# -> 5299     yield from self.bound.transform(
#    5300         input,
#    5301         self._merge_configs(config),
#    5302         **{**self.kwargs, **kwargs},
#    5303     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1287             final = ichunk
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:411, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     404 except BaseException as e:
#     405     run_manager.on_llm_error(
#     406         e,
#     407         response=LLMResult(
#     408             generations=[[generation]] if generation else []
#     409         ),
#     410     )
# --> 411     raise e
#     412 else:
#     413     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:391, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     388     self.rate_limiter.acquire(blocking=True)
#     390 try:
# --> 391     for chunk in self._stream(messages, stop=stop, **kwargs):
#     392         if chunk.message.id is None:
#     393             chunk.message.id = f"run-{run_manager.run_id}"
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_groq\chat_models.py:507, in ChatGroq._stream(self, messages, stop, run_manager, **kwargs)
#     505 # groq api does not support streaming with tools yet
#     506 if "tools" in kwargs:
# --> 507     response = self.client.create(
#     508         messages=message_dicts, **{**params, **kwargs}
#     509     )
#     510     chat_result = self._create_chat_result(response)
#     511     generation = chat_result.generations[0]
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\resources\chat\completions.py:287, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     146 def create(
#     147     self,
#     148     *,
#    (...)
#     175     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     176 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     177     """
#     178     Creates a model response for the given chat conversation.
#     179
#    (...)
#     285       timeout: Override the client-level default timeout for this request, in seconds
#     286     """
# --> 287     return self._post(
#     288         "/openai/v1/chat/completions",
#     289         body=maybe_transform(
#     290             {
#     291                 "messages": messages,
#     292                 "model": model,
#     293                 "frequency_penalty": frequency_penalty,
#     294                 "function_call": function_call,
#     295                 "functions": functions,
#     296                 "logit_bias": logit_bias,
#     297                 "logprobs": logprobs,
#     298                 "max_tokens": max_tokens,
#     299                 "n": n,
#     300                 "parallel_tool_calls": parallel_tool_calls,
#     301                 "presence_penalty": presence_penalty,
#     302                 "response_format": response_format,
#     303                 "seed": seed,
#     304                 "stop": stop,
#     305                 "stream": stream,
#     306                 "temperature": temperature,
#     307                 "tool_choice": tool_choice,
#     308                 "tools": tools,
#     309                 "top_logprobs": top_logprobs,
#     310                 "top_p": top_p,
#     311                 "user": user,
#     312             },
#     313             completion_create_params.CompletionCreateParams,
#     314         ),
#     315         options=make_request_options(
#     316             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     317         ),
#     318         cast_to=ChatCompletion,
#     319         stream=stream or False,
#     320         stream_cls=Stream[ChatCompletionChunk],
#     321     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\_base_client.py:1244, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1230 def post(
#    1231     self,
#    1232     path: str,
#    (...)
#    1239     stream_cls: type[_StreamT] | None = None,
#    1240 ) -> ResponseT | _StreamT:
#    1241     opts = FinalRequestOptions.construct(
#    1242         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1243     )
# -> 1244     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\_base_client.py:936, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927 def request(
#     928     self,
#     929     cast_to: Type[ResponseT],
#    (...)
#     934     stream_cls: type[_StreamT] | None = None,
#     935 ) -> ResponseT | _StreamT:
# --> 936     return self._request(
#     937         cast_to=cast_to,
#     938         options=options,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941         remaining_retries=remaining_retries,
#     942     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1036         err.response.read()
#    1038     log.debug("Re-raising status error")
# -> 1039     raise self._make_status_error_from_response(err.response) from None
#    1041 return self._process_response(
#    1042     cast_to=cast_to,
#    1043     options=options,
#    (...)
#    1047     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1048 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}

# %%
agent_executor.invoke({"input":"What is machine learning"})
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 agent_executor.invoke({"input":"What is machine learning"})
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\chains\base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\chains\base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output, intermediate_steps, run_manager=run_manager
#    1635         )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1331, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1331, in <listcomp>(.0)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:1359, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1356     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1358     # Call the LLM to see what to do.
# -> 1359     output = self._action_agent.plan(
#    1360         intermediate_steps,
#    1361         callbacks=run_manager.get_child() if run_manager else None,
#    1362         **inputs,
#    1363     )
#    1364 except OutputParserException as e:
#    1365     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain\agents\agent.py:577, in RunnableMultiActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     569 final_output: Any = None
#     570 if self.stream_runnable:
#     571     # Use streaming to make sure that the underlying LLM is invoked in a
#     572     # streaming
#    (...)
#     575     # Because the response from the plan is not a generator, we need to
#     576     # accumulate the output into final output and return that.
# --> 577     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     578         if final_output is None:
#     579             final_output = chunk
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:3261, in RunnableSequence.stream(self, input, config, **kwargs)
#    3255 def stream(
#    3256     self,
#    3257     input: Input,
#    3258     config: Optional[RunnableConfig] = None,
#    3259     **kwargs: Optional[Any],
#    3260 ) -> Iterator[Output]:
# -> 3261     yield from self.transform(iter([input]), config, **kwargs)
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:3248, in RunnableSequence.transform(self, input, config, **kwargs)
#    3242 def transform(
#    3243     self,
#    3244     input: Iterator[Input],
#    3245     config: Optional[RunnableConfig] = None,
#    3246     **kwargs: Optional[Any],
#    3247 ) -> Iterator[Output]:
# -> 3248     yield from self._transform_stream_with_config(
#    3249         input,
#    3250         self._transform,
#    3251         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3252         **kwargs,
#    3253     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:2054, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2052 try:
#    2053     while True:
# -> 2054         chunk: Output = context.run(next, iterator)  # type: ignore
#    2055         yield chunk
#    2056         if final_output_supported:
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:3211, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3208     else:
#    3209         final_pipeline = step.transform(final_pipeline, config)
# -> 3211 yield from final_pipeline
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:1272, in Runnable.transform(self, input, config, **kwargs)
#    1269 final: Input
#    1270 got_first_val = False
# -> 1272 for ichunk in input:
#    1273     # The default implementation of transform is to buffer input and
#    1274     # then call stream.
#    1275     # It'll attempt to gather all input into a single chunk using
#    1276     # the `+` operator.
#    1277     # If the input is not addable, then we'll assume that we can
#    1278     # only operate on the last chunk,
#    1279     # and we'll iterate until we get to the last chunk.
#    1280     if not got_first_val:
#    1281         final = ichunk
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:5299, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5293 def transform(
#    5294     self,
#    5295     input: Iterator[Input],
#    5296     config: Optional[RunnableConfig] = None,
#    5297     **kwargs: Any,
#    5298 ) -> Iterator[Output]:
# -> 5299     yield from self.bound.transform(
#    5300         input,
#    5301         self._merge_configs(config),
#    5302         **{**self.kwargs, **kwargs},
#    5303     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\runnables\base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1287             final = ichunk
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:411, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     404 except BaseException as e:
#     405     run_manager.on_llm_error(
#     406         e,
#     407         response=LLMResult(
#     408             generations=[[generation]] if generation else []
#     409         ),
#     410     )
# --> 411     raise e
#     412 else:
#     413     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:391, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     388     self.rate_limiter.acquire(blocking=True)
#     390 try:
# --> 391     for chunk in self._stream(messages, stop=stop, **kwargs):
#     392         if chunk.message.id is None:
#     393             chunk.message.id = f"run-{run_manager.run_id}"
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\langchain_groq\chat_models.py:507, in ChatGroq._stream(self, messages, stop, run_manager, **kwargs)
#     505 # groq api does not support streaming with tools yet
#     506 if "tools" in kwargs:
# --> 507     response = self.client.create(
#     508         messages=message_dicts, **{**params, **kwargs}
#     509     )
#     510     chat_result = self._create_chat_result(response)
#     511     generation = chat_result.generations[0]
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\resources\chat\completions.py:287, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     146 def create(
#     147     self,
#     148     *,
#    (...)
#     175     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     176 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     177     """
#     178     Creates a model response for the given chat conversation.
#     179
#    (...)
#     285       timeout: Override the client-level default timeout for this request, in seconds
#     286     """
# --> 287     return self._post(
#     288         "/openai/v1/chat/completions",
#     289         body=maybe_transform(
#     290             {
#     291                 "messages": messages,
#     292                 "model": model,
#     293                 "frequency_penalty": frequency_penalty,
#     294                 "function_call": function_call,
#     295                 "functions": functions,
#     296                 "logit_bias": logit_bias,
#     297                 "logprobs": logprobs,
#     298                 "max_tokens": max_tokens,
#     299                 "n": n,
#     300                 "parallel_tool_calls": parallel_tool_calls,
#     301                 "presence_penalty": presence_penalty,
#     302                 "response_format": response_format,
#     303                 "seed": seed,
#     304                 "stop": stop,
#     305                 "stream": stream,
#     306                 "temperature": temperature,
#     307                 "tool_choice": tool_choice,
#     308                 "tools": tools,
#     309                 "top_logprobs": top_logprobs,
#     310                 "top_p": top_p,
#     311                 "user": user,
#     312             },
#     313             completion_create_params.CompletionCreateParams,
#     314         ),
#     315         options=make_request_options(
#     316             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     317         ),
#     318         cast_to=ChatCompletion,
#     319         stream=stream or False,
#     320         stream_cls=Stream[ChatCompletionChunk],
#     321     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\_base_client.py:1244, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1230 def post(
#    1231     self,
#    1232     path: str,
#    (...)
#    1239     stream_cls: type[_StreamT] | None = None,
#    1240 ) -> ResponseT | _StreamT:
#    1241     opts = FinalRequestOptions.construct(
#    1242         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1243     )
# -> 1244     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\_base_client.py:936, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927 def request(
#     928     self,
#     929     cast_to: Type[ResponseT],
#    (...)
#     934     stream_cls: type[_StreamT] | None = None,
#     935 ) -> ResponseT | _StreamT:
# --> 936     return self._request(
#     937         cast_to=cast_to,
#     938         options=options,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941         remaining_retries=remaining_retries,
#     942     )
#
# File c:\Users\Kempsly\Desktop\Genai_projects\Q&A-Chatbot\venv\Lib\site-packages\groq\_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1036         err.response.read()
#    1038     log.debug("Re-raising status error")
# -> 1039     raise self._make_status_error_from_response(err.response) from None
#    1041 return self._process_response(
#    1042     cast_to=cast_to,
#    1043     options=options,
#    (...)
#    1047     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1048 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}
